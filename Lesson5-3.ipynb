# %%
import numpy as np

students = np.array([
    [67, 94, 65],
    [88, 82, 78],
    [90, 90, 90]])

# %%
import pandas as pd

pd.DataFrame(data=students,
             index=['stu1','stu2','stu3'],
             columns=['國文','英文','數學']
             )
# Out:
#       國文  英文  數學
# stu1  67  94  65
# stu2  88  82  78
# stu3  90  90  90

# %%
import numpy as np
import pandas as pd

data = np.random.randint(50,high=101,size=(50, 5))
students = pd.DataFrame(data,
             columns=['國文','英文','數學','地理','探討'])
students
# Out:
#      國文   英文   數學   地理   探討
# 0    72   68   99   66   87
# 1    78   74   84   72   63
# 2    84   89   88   89   93
# 3    67   74   67   74   64
# 4    54   89   94   75   92
# 5    88   74   55   51   84
# 6    76   87   79   86   69
# 7    89   51   69   52  100
# 8    89   85   91   78   82
# 9    89   56   84   75   57
# 10   53   64   63   85   61
# 11   77   70   73   89   72
# 12   66   58   96   96   83
# 13   74   88   87   52   78
# 14   86   86   88   54   98
# 15   54   53   88   70   80
# 16   52   71   54   52   50
# 17   93   82   86   89   72
# 18   98   75   91   60   67
# 19   90   71   87  100   95
# 20   52   65   68   68   71
# 21   80   51   56   67   88
# 22   77   82   51   85   97
# 23   74   61   63   90   72
# 24   51   90   95   92   79
# 25  100   72   99   60   92
# 26   93   93   79   81   78
# 27   78   51   95   76   60
# 28   83   51   96   88   63
# 29   52   73   62   77   88
# 30   81   51   68   52   99
# 31   77   52   61   77   78
# 32   96   81  100   79  100
# 33   77  100   67   54   88
# 34   94   64   80   81   76
# 35   86   68  100   64   93
# 36   64   67   88   67   54
# 37   69   75   58   87   82
# 38   97   71   59   99   56
# 39   60   75   58   54   53
# 40   96   98   85   92   95
# 41   55   97   72   79   97
# 42   58   72   99   79   88
# 43   62   75   63   94   89
# 44   76   59   67   69   71
# 45   90   55   92   64   55
# 46   62   52   60  100   91
# 47   89   84   52   74   61
# 48   56   73   58   59   79
# 49   92   53   91   81   51

# %%
import random
def get_names(nums:int=10)->list[str]:
    with open('names.txt',encoding='utf-8') as file:
        content = file.read()
        names = content.split("\n")
        randam_names = random.sample(names,nums)
        
    return randam_names

get_names(5)
# Out:
# ['王明昇', '劉耿琦', '劉嘉泰', '林玉佩', '盧文啟']

# %%
import numpy as np
import pandas as pd

student_nums = 50
data = np.random.randint(50,high=101,size=(student_nums, 5))
students = pd.DataFrame(data,
             columns=['國文','英文','數學','地理','探討'],
             index=get_names(student_nums))
type(students)
# Out:
# pandas.core.frame.DataFrame

# %%
students.to_csv('students1.csv',index=True,encoding='utf-8-sig')
students.to_excel('students1.xlsx',sheet_name='sheet1')
students
# Out:
#       國文   英文  數學  地理   探討
# 黃旻林   82   76  54  83   77
# 黃麗美   66   87  61  70   83
# 王品星  100   71  66  52   73
# 張慧君   63   68  69  86   82
# 吳欣書   51   53  73  91   72
# 昌嘉洋   62   67  93  66   93
# 翁鈺婷   92  100  65  88   95
# 吳昕婷   70   82  56  52   60
# 崔孝憲   91   95  60  54   58
# 王展人   70   77  71  78   68
# 謝哲維   85   94  55  99   93
# 馮淑芬   88   86  86  70   67
# 蔡明平   81   50  88  76   98
# 蔡孟泉   83   62  73  53   63
# 魏秋萍   93   75  75  99   59
# 林群清   59   53  83  95   72
# 王柏聖   68   89  70  98   57
# 元延辛   85   81  75  80   97
# 白世宏   59   91  94  87   78
# 余宗儒   71   53  75  66   84
# 黃心航   87   87  65  54  100
# 艾巧夫   54   86  71  54   69
# 邱亭君   74   59  78  68   82
# 賴佳雯   85   88  67  84   51
# 陳嘉淑   93   95  88  54   65
# 劉雯芬   87   69  86  90   70
# 黃名明   55   94  78  77   66
# 楊綺芬  100   76  61  89   76
# 王德城   73   99  99  87   92
# 方雅慧   92   67  81  71   93
# 黃雅慧   61   71  52  64   92
# 陳姵彬   88   69  77  55   95
# 杜儀鳳   60   89  81  88   52
# 郭致恬   65   91  82  80   96
# 周怡啟   54   73  96  56   73
# 賴又琦   95  100  96  83   92
# 唐雪豪   97   72  78  66   87
# 張俊傑   61   58  80  63   69
# 王雅慧   90   77  84  90   88
# 黎惠雯   91   55  71  63   93
# 葉軍仰   76   76  85  91   86
# 鄭琇亞   61   96  64  73   57
# 戴萱能   53   71  66  70   90
# 羅幸娥  100   96  95  96   98
# 劉林中   68   52  60  56   73
# 趙家豪   63   59  79  97   69
# 謝貞妃   67   84  83  71   78
# 黃善迪   77   53  51  65   77
# 吳淑惠   57   62  98  59   59
# 郭淑枝   72   83  65  58   99
