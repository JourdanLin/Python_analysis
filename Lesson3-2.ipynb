# %%
p1 = {'name' : '學生A',
       'age' : 18,
       'city' : '台北市'}
p1
# Out:
# {'name': '學生A', 'age': 18, 'city': '台北市'}

# %%
print (p1['name'])
print (p1.get('age'))
print (p1.get('city'))
# Out:
# 學生A
# 18
# 台北市

# %%
del p1['city']
print (p1)
# Out:
# {'name': '學生A', 'age': 18}

# %% [markdown]
# 1 - 如何依序取出串列資料和映射資料的元素值
#
# 2 - for_in 迴圈

# %%
fruits = ['apple', 'banana', 'orange']
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# orange

# %%
for fruit in enumerate(fruits):
    print (fruit)
# Out:
# (0, 'apple')
# (1, 'banana')
# (2, 'orange')

# %%
for index, fruit in enumerate(fruits):
    print (index, fruit, sep='->')
    print ("================")
# Out:
# 0->apple
# ...
# 1->banana
# ...
# 2->orange
# ...

# %%
cities = { 'Taipei' : '台北市', 
          'New Taipei' : '新北市',
          'Taoyuan' : '桃園市',
           'Taichung' : '台中市',
           'tainan' : '台南市',
           'Kaohsiung' : '高雄市',
           'Keelung' : '基隆市', 
           'Hsinchu' : '新竹市',
           'chiayi' : '嘉義市',
           'hualien' : '花蓮市'}
for key, value in cities.items(): 
    print (f"{key} : {value}")
# Out:
# Taipei : 台北市
# New Taipei : 新北市
# Taoyuan : 桃園市
# Taichung : 台中市
# tainan : 台南市
# Kaohsiung : 高雄市
# Keelung : 基隆市
# Hsinchu : 新竹市
# chiayi : 嘉義市
# hualien : 花蓮市

# %%
# 建立一個學生 dictionary
# {'name' : 'value', 'chines': 78 , 'english' : 98, 'mact' : 67, 'history' : 87, 'health' : 76}
# 請用List 建立50 個學生的資料

import random

students = []
for i in range(50):
    student = {'name' : f'學生{i}','chinese' : random.randint(50, 100),'english' : random.randint(50, 100),
               'math' : random.randint(50, 100),'history' : random.randint(50, 100), 'health' : random.randint(50, 100)}
    students.append(student)
  
students
# Out:
# [{'name': '學生0',
#   'chinese': 98,
#   'english': 80,
#   'math': 68,
#   'history': 58,
#   'health': 56},
#  {'name': '學生1',
#   'chinese': 82,
#   'english': 71,
#   'math': 62,
#   'history': 62,
#   'health': 80},
#  {'name': '學生2',
#   'chinese': 57,
#   'english': 56,
#   'math': 78,
#   'history': 83,
#   'health': 61},
#  {'name': '學生3',
#   'chinese': 83,
#   'english': 56,
#   'math': 92,
#   'history': 58,
#   'health': 50},
#  {'name': '學生4',
#   'chinese': 61,
#   'english': 99,
#   'math': 83,
#   'history': 52,
#   'health': 87},
#  {'name': '學生5',
#   'chinese': 55,
#   'english': 70,
#   'math': 91,
#   'history': 53,
#   'health': 51},
#  {'name': '學生6',
#   'chinese': 80,
#   'english': 90,
#   'math': 83,
#   'history': 80,
#   'health': 84},
#  {'name': '學生7',
#   'chinese': 55,
#   'english': 55,
#   'math': 60,
#   'history': 80,
#   'health': 80},
#  {'name': '學生8',
#   'chinese': 87,
#   'english': 54,
#   'math': 84,
#   'history': 76,
#   'health': 91},
# ...

# %%
students = []

for i in range(1,51):
    students.append (   
        {
         'name': f'student{i}',
         'chinese' : random.randint(50,100),
         'english' : random.randint(50,100),
         'math' : random.randint(50,100),
         'history' : random.randint(50,100),
         'health' : random.randint(50,100)}
    )

students_str = str(students)
#students_str

type(students)
# Out:
# list

# %%
students = ['Alice', 'Bob', 'Charlie']

# %%
for socres in students:
    print (socres)
# Out:
# {'name': 'student1', 'chinese': 90, 'english': 72, 'math': 50, 'history': 93, 'health': 76}
# {'name': 'student2', 'chinese': 95, 'english': 80, 'math': 53, 'history': 81, 'health': 69}
# {'name': 'student3', 'chinese': 78, 'english': 54, 'math': 87, 'history': 82, 'health': 82}
# {'name': 'student4', 'chinese': 67, 'english': 63, 'math': 58, 'history': 69, 'health': 84}
# {'name': 'student5', 'chinese': 51, 'english': 93, 'math': 99, 'history': 84, 'health': 50}
# {'name': 'student6', 'chinese': 99, 'english': 58, 'math': 96, 'history': 62, 'health': 67}
# {'name': 'student7', 'chinese': 90, 'english': 52, 'math': 79, 'history': 58, 'health': 72}
# {'name': 'student8', 'chinese': 71, 'english': 88, 'math': 88, 'history': 77, 'health': 82}
# {'name': 'student9', 'chinese': 60, 'english': 78, 'math': 91, 'history': 77, 'health': 80}
# {'name': 'student10', 'chinese': 97, 'english': 54, 'math': 81, 'history': 94, 'health': 80}
# ...

# %%
students_str = '\n'.join([
    f"姓名:{student['name']}, "
    f"國文:{student['chinese']}, "
    f"英文:{student['english']}, "
    f"數學:{student['math']}, "
    f"歷史:{student['history']}, "
    f"健康:{student['health']}"
    for student in students
])

print(students_str) 
type(students_str)
# Out:
# 姓名:student1, 國文:90, 英文:72, 數學:50, 歷史:93, 健康:76
# 姓名:student2, 國文:95, 英文:80, 數學:53, 歷史:81, 健康:69
# 姓名:student3, 國文:78, 英文:54, 數學:87, 歷史:82, 健康:82
# 姓名:student4, 國文:67, 英文:63, 數學:58, 歷史:69, 健康:84
# 姓名:student5, 國文:51, 英文:93, 數學:99, 歷史:84, 健康:50
# 姓名:student6, 國文:99, 英文:58, 數學:96, 歷史:62, 健康:67
# 姓名:student7, 國文:90, 英文:52, 數學:79, 歷史:58, 健康:72
# 姓名:student8, 國文:71, 英文:88, 數學:88, 歷史:77, 健康:82
# 姓名:student9, 國文:60, 英文:78, 數學:91, 歷史:77, 健康:80
# 姓名:student10, 國文:97, 英文:54, 數學:81, 歷史:94, 健康:80
# 姓名:student11, 國文:76, 英文:82, 數學:70, 歷史:51, 健康:60
# 姓名:student12, 國文:78, 英文:64, 數學:99, 歷史:92, 健康:60
# 姓名:student13, 國文:76, 英文:91, 數學:67, 歷史:86, 健康:74
# 姓名:student14, 國文:64, 英文:90, 數學:50, 歷史:57, 健康:57
# 姓名:student15, 國文:72, 英文:73, 數學:52, 歷史:75, 健康:78
# 姓名:student16, 國文:85, 英文:60, 數學:66, 歷史:96, 健康:85
# 姓名:student17, 國文:94, 英文:58, 數學:79, 歷史:77, 健康:70
# 姓名:student18, 國文:98, 英文:75, 數學:70, 歷史:82, 健康:59
# 姓名:student19, 國文:52, 英文:61, 數學:65, 歷史:95, 健康:76
# 姓名:student20, 國文:56, 英文:59, 數學:77, 歷史:60, 健康:93
# ...

# %%
print (students_str,file=open('students.txt',mode='w',encoding='utf-8'))
